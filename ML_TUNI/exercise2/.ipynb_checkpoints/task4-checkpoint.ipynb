# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %% [markdown]
# Generate signal

# %%
n = np.arange(0, 100)
fo = 0.1

vector1 = np.zeros(500)
vector2 = np.zeros(300)
vector_sin = np.cos(2 * np.pi * fo * n)
signal_without_noise = np.concatenate((vector1, vector_sin, vector2))

# %% [markdown]
# Gaussian noise signal

# %%
gaussian_noise = np.sqrt(0.5) * np.random.randn(signal_without_noise.size)

# %% [markdown]
# Add noise to signal:

# %%
window_size = 100
noisy_signal = signal_without_noise + gaussian_noise

#expanded_noisy = np.concatenate(( np.zeros(int(window_size/2)), noisy_signal, np.zeros(int(window_size/2))))

# %% [markdown]
# Deterministic detector:

# %%
determ_detector = []
for i in range(len(n)):
    determ_detector.append( np.sum (expanded_noisy[i:i+window_size] * np.cos(2*np.pi*fo*n[0:100])))

# %% [markdown]
# Stochastic detector:

# %%
random_signal1 = []

for i in range(10):
    random_signal1.append(np.convolve(np.cos(2*np.pi*fo*n[i*100:i*100+window_size]), noisy_signal[i*100:i*100+window_size],'same'))

random_signal1 = np.asarray(random_signal1).flatten() #put array to one dimension

# %%
random_signal2 = []

h = np.exp(-2 * np.pi * 1j * fo * n)
y = np.abs(np.convolve(h, noisy_signal, 'same'))
#for k in range(10):
#    h = np.exp(-2 * np.pi * 1j * fo * n[k*100:k*100+window_size])
#    y = np.abs(np.convolve(h, noisy_signal[k*100:k*100+window_size], 'same'))
#    random_signal2.append(y)

#random_sig2 = np.asarray(random_signal2).flatten()
plt.plot(y)

# %%
random_signal3 = []

for i in range(len(n)):
    random_signal3.append(np.convolve(np.cos(2*np.pi*fo*n[0:100]), expanded_noisy[i:i+window_size],'valid'))

# %%
fig, ax = plt.subplots(4, 1)

ax[0].plot(n, signal_without_noise)
ax[1].plot(n, noisy_signal)
ax[2].plot(n, determ_detector)
ax[3].plot(n, random_signal2)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-3f4eae5e1401> in <module>
#       4 ax[1].plot(n, noisy_signal)
#       5 ax[2].plot(n, determ_detector)
# ----> 6 ax[3].plot(n, random_signal2)
#       7
#       8 plt.show()
#
# ~/.conda/envs/PatternRecogMLExercises/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1664         """
#    1665         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
# -> 1666         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1667         for line in lines:
#    1668             self.add_line(line)
#
# ~/.conda/envs/PatternRecogMLExercises/lib/python3.7/site-packages/matplotlib/axes/_base.py in __call__(self, *args, **kwargs)
#     223                 this += args[0],
#     224                 args = args[1:]
# ...
